# %%
import torch

# %%
tensorld = torch.tensor([1,2,3])
tensorld.dtype
# Out:
# torch.int64

# %%
tensorld.to(torch.float32)
# Out:
# tensor([1., 2., 3.])

# %%
def func(*args):
    print(args)
    print(len(args))

func(*['a','b','c'])
func(['a', 'b', 'c'])
# Out:
# ('a', 'b', 'c')
# 3
# (['a', 'b', 'c'],)
# 1
